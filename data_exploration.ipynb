# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('df4.csv')

# %%
df.head()
# Out:
#    Sex Equipment   Age  BodyweightKg  Best3SquatKg  Best3BenchKg  \
# 0    0     Wraps  29.0          59.8         105.0          55.0
# 1    0     Wraps  29.0          58.5         120.0          67.5
# 2    0     Wraps  23.0          60.0         105.0          72.5
# 3    0     Wraps  45.0         104.0         140.0          80.0
# 4    0     Wraps  37.0          74.0         142.5          82.5
#
#    Best3DeadliftKg  TotalKg  EquipFeat
# 0            130.0    290.0          2
# 1            145.0    332.5          2
# 2            132.5    310.0          2
# 3            170.0    390.0          2
# 4            145.0    370.0          2

# %%
sns.set_style('whitegrid')

# %%
sns.lmplot('Equipment','TotalKg',data=df, hue='Age',
           palette='coolwarm',size=6,aspect=1,fit_reg=False)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:580: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('darkgrid')
g = sns.FacetGrid(df,hue="Sex",palette='coolwarm',size=6,aspect=2)
g = g.map(plt.hist,'TotalKg',bins=20,alpha=0.7)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:316: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232892 entries, 0 to 232891
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Sex              232892 non-null  int64
#  1   Equipment        232892 non-null  object
#  2   Age              232892 non-null  float64
#  3   BodyweightKg     232892 non-null  float64
#  4   Best3SquatKg     232892 non-null  float64
#  5   Best3BenchKg     232892 non-null  float64
#  6   Best3DeadliftKg  232892 non-null  float64
#  7   TotalKg          232892 non-null  float64
#  8   EquipFeat        232892 non-null  int64
# dtypes: float64(6), int64(2), object(1)
# memory usage: 16.0+ MB

# %%
kmeans.fit(df.drop(['Equipment','EquipFeat'],axis=1))
# Out:
# KMeans(n_clusters=4)

# %%
kmeans.cluster_centers_
# Out:
# array([[1.68628462e-01, 2.93111092e+01, 6.58681856e+01, 1.06852437e+02,
#         6.20362997e+01, 1.28806701e+02, 2.97694967e+02],
#        [9.99242998e-01, 2.99841030e+01, 1.08093615e+02, 3.10550908e+02,
#         2.06139551e+02, 2.96263359e+02, 8.12952770e+02],
#        [7.83117932e-01, 2.90899781e+01, 7.96658278e+01, 1.67786821e+02,
#         1.08371835e+02, 1.91663697e+02, 4.67821680e+02],
#        [9.76435467e-01, 2.95725272e+01, 9.26407679e+01, 2.26069038e+02,
#         1.49434937e+02, 2.44327191e+02, 6.19830511e+02]])

# %%
kmeans.labels_
# Out:
# array([0, 0, 0, ..., 2, 2, 0])

# %%
x = df['BodyweightKg']
y = df['Best3BenchKg']

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(x,y,c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(x,y,c=df['EquipFeat'],cmap='rainbow')

# %%
x = df['BodyweightKg']
y = df['Best3SquatKg']
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(x,y,c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(x,y,c=df['EquipFeat'],cmap='rainbow')

# %%
x = df['BodyweightKg']
y = df['Best3DeadliftKg']
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(x,y,c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(x,y,c=df['EquipFeat'],cmap='rainbow')

# %%
x = df['BodyweightKg']
y = df['TotalKg']
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(x,y,c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(x,y,c=df['EquipFeat'],cmap='rainbow')

# %%
x = df['Age']
y = df['TotalKg']
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(x,y,c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(x,y,c=df['EquipFeat'],cmap='rainbow')

# %%
x = df['Sex']
y = df['Equipment']
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(x,y,c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(x,y,c=df['EquipFeat'],cmap='rainbow')

# %%
x = df['Equipment']
y = df['Equipment']
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(x,y,c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(x,y,c=df['EquipFeat'],cmap='rainbow')

# %%
dfm = df[df["Sex"] == 1]

# %%
dff = df[df["Sex"] == 0]

# %%
dff.head()
# Out:
#    Sex Equipment   Age  BodyweightKg  Best3SquatKg  Best3BenchKg  \
# 0    0     Wraps  29.0          59.8         105.0          55.0
# 1    0     Wraps  29.0          58.5         120.0          67.5
# 2    0     Wraps  23.0          60.0         105.0          72.5
# 3    0     Wraps  45.0         104.0         140.0          80.0
# 4    0     Wraps  37.0          74.0         142.5          82.5
#
#    Best3DeadliftKg  TotalKg  EquipFeat
# 0            130.0    290.0          2
# 1            145.0    332.5          2
# 2            132.5    310.0          2
# 3            170.0    390.0          2
# 4            145.0    370.0          2

# %%
kmeans = KMeans(n_clusters=4)
kmeans.fit(dfm.drop(['Equipment','EquipFeat'],axis=1))
# Out:
# KMeans(n_clusters=4)

# %%
x = dfm['Age']
y = dfm['TotalKg']
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(10,6))
ax1.set_title('K Means')
ax1.scatter(x,y,c=kmeans.labels_,cmap='rainbow')
ax2.set_title("Original")
ax2.scatter(x,y,c=dfm['EquipFeat'],cmap='rainbow')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop(['Equipment','Sex'],axis=1), 
                                                    df['Sex'], test_size=0.30, 
                                                    random_state=101)

# %%
from sklearn.linear_model import LogisticRegression
logmodel = LogisticRegression(max_iter=1000)
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.86      0.86     22528
#            1       0.93      0.93      0.93     47340
#
#     accuracy                           0.91     69868
#    macro avg       0.89      0.89      0.89     69868
# weighted avg       0.91      0.91      0.91     69868

# %%
X = df.drop(['Equipment','TotalKg','Best3SquatKg'],axis=1)
y = df['Best3SquatKg']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
print(lm.intercept_)
# Out:
# -10.123401201847457

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                  Coefficient
# Sex               -16.054366
# Age                -0.251315
# BodyweightKg        0.068643
# Best3BenchKg        0.677167
# Best3DeadliftKg     0.604396
# EquipFeat           7.121685

# %%
predictions = lm.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
sns.distplot((y_test-predictions),bins=50);
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print(classification_report(y_test,predictions))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-49b4b26ceb45> in <module>
# ----> 1 print(classification_report(y_test,predictions))
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    1927     """
#    1928
# -> 1929     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1930
#    1931     labels_given = True
#
# ...

# %%
df['Age'] = np.round(df['Age'])

# %%
df.iloc[146357]
# Out:
# Sex                    0
# Equipment            Raw
# Age                   24
# BodyweightKg       71.53
# Best3SquatKg         155
# Best3BenchKg        87.5
# Best3DeadliftKg    187.5
# TotalKg              430
# EquipFeat              0
# Name: 146357, dtype: object

# %%
df.to_csv('df4.csv', index=False)

# %%
import plotly.io as pio

# %%
# %pip install plotly
# Out:
# ...
#   Using cached plotly-4.14.3-py2.py3-none-any.whl (13.2 MB)
# ...
#   Using cached retrying-1.3.3.tar.gz (10 kB)
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11434 sha256=36685695954e49db59c6ad75017412a52d518f2af730e77391e4c52ce8da5c3d
#   Stored in directory: c:\users\julian chavez\appdata\local\pip\cache\wheels\c4\a7\48\0a434133f6d56e878ca511c0e6c38326907c0792f67b476e56
# Successfully built retrying
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
plotly_template = pio.templates["plotly_dark"]
plotly_template.layout
# Out:
# Layout({
#     'annotationdefaults': {'arrowcolor': '#f2f5fa', 'arrowhead': 0, 'arrowwidth': 1},
#     'autotypenumbers': 'strict',
#     'coloraxis': {'colorbar': {'outlinewidth': 0, 'ticks': ''}},
#     'colorscale': {'diverging': [[0, '#8e0152'], [0.1, '#c51b7d'], [0.2,
#                                  '#de77ae'], [0.3, '#f1b6da'], [0.4, '#fde0ef'],
#                                  [0.5, '#f7f7f7'], [0.6, '#e6f5d0'], [0.7,
#                                  '#b8e186'], [0.8, '#7fbc41'], [0.9, '#4d9221'],
#                                  [1, '#276419']],
#                    'sequential': [[0.0, '#0d0887'], [0.1111111111111111,
#                                   '#46039f'], [0.2222222222222222, '#7201a8'],
#                                   [0.3333333333333333, '#9c179e'],
#                                   [0.4444444444444444, '#bd3786'],
#                                   [0.5555555555555556, '#d8576b'],
# ...
